# %%
import mysql.connector as conn

# %%
dbConn = conn.connect(host = 'localhost', user = 'root', passwd = 'mysql')

# %%
cursor = dbConn.cursor()

# %%
cursor.execute("SHOW DATABASES;")
cursor.fetchall()
# Out:
# [('database1',),
#  ('db1',),
#  ('information_schema',),
#  ('lec1_db',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('test1_py',),
#  ('test1_sql',)]

# %%
cursor.execute("SELECT * FROM lec1_db.glass_table")

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
# ...

# %%
cursor.execute("SELECT * FROM lec1_db.table1")

# %%
cursor.fetchall()
# Out:
# [(5001, 'student1', 105001, 'class11'),
#  (5002, 'student2', 105002, 'FSDS'),
#  (5003, 'student3', 105003, 'FSDS'),
#  (5004, 'student4', 105004, 'FSDS')]

# %%
cursor.execute("SELECT col, col5, col10 FROM lec1_db.glass_table")
cursor.fetchall()
# Out:
# [(1, 1.1, 0.0),
#  (2, 1.36, 0.0),
#  (3, 1.54, 0.0),
#  (4, 1.29, 0.0),
#  (5, 1.24, 0.0),
#  (6, 1.62, 0.26),
#  (7, 1.14, 0.0),
#  (8, 1.05, 0.0),
#  (9, 1.37, 0.0),
#  (10, 1.36, 0.11),
#  (11, 1.56, 0.24),
#  (12, 1.27, 0.0),
#  (13, 1.4, 0.24),
#  (14, 1.27, 0.17),
#  (15, 1.31, 0.0),
#  (16, 1.23, 0.0),
#  (17, 1.16, 0.0),
#  (18, 0.89, 0.0),
#  (19, 1.18, 0.0),
#  (20, 1.69, 0.07),
#  (21, 1.49, 0.19),
#  (22, 0.29, 0.0),
#  (23, 1.29, 0.0),
#  (24, 1.35, 0.0),
#  (25, 1.15, 0.0),
#  (26, 1.21, 0.0),
#  (27, 1.41, 0.0),
#  (28, 1.33, 0.0),
#  (29, 1.43, 0.0),
#  (30, 1.28, 0.0),
#  (31, 1.3, 0.14),
#  (32, 1.14, 0.0),
#  (33, 1.23, 0.22),
#  (34, 1.38, 0.06),
#  (35, 1.34, 0.0),
#  (36, 1.21, 0.0),
#  (37, 1.32, 0.0),
#  (38, 1.35, 0.0),
#  (39, 0.47, 0.0),
#  (40, 0.47, 0.0),
#  (41, 1.12, 0.0),
#  (42, 1.2, 0.0),
#  (43, 1.33, 0.0),
#  (44, 0.72, 0.0),
#  (45, 1.19, 0.3),
#  (46, 1.35, 0.0),
#  (47, 1.18, 0.16),
#  (48, 0.71, 0.1),
#  (49, 0.79, 0.0),
#  (50, 1.23, 0.0),
# ...

# %%
cursor.execute("SELECT * FROM lec1_db.glass_table WHERE col = 4")
cursor.fetchall()
# Out:
# [(4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1)]

# %%
cursor.execute("SELECT * FROM lec1_db.glass_table WHERE col = 4 and col11 = 0")
cursor.fetchall()
# Out:
# []

# %%
# Delete

# %%
cursor.execute("DELETE FROM lec1_db.glass_table WHERE col = 4")
# Out:
# []

# %%
cursor.execute("SELECT * FROM lec1_db.glass_table")
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("DELETE FROM lec1_db.glass_table WHERE col = 5")

# %%
cursor.execute("SELECT * FROM lec1_db.glass_table")
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
# ...

# %%
dbConn.commit()

# %%
cursor.execute("SELECT * FROM lec1_db.glass_table")
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
# ...

# %%
# Update

# %%
cursor.execute("SELECT * FROM lec1_db.glass_table")

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("UPDATE lec1_db.glass_table SET col = 6, col2 = 8 WHERE col = 1")

# %%
dbConn.commit()

# %%
cursor.execute("SELECT * FROM lec1_db.glass_table")
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("SELECT * FROM lec1_db.glass_table WHERE col = 6")
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1)]

# %%
cursor.execute("select count(col), col2 FROM lec1_db.glass_table GROUP BY col")

# %%
cursor.fetchall()
# Out:
# [(2, 8.0),
#  (1, 1.51761),
#  (1, 1.51618),
#  (1, 1.51743),
#  (1, 1.51756),
#  (1, 1.51918),
#  (1, 1.51755),
#  (1, 1.51571),
#  (1, 1.51763),
#  (1, 1.51589),
#  (1, 1.51748),
#  (1, 1.51763),
#  (1, 1.51761),
#  (1, 1.51784),
#  (1, 1.52196),
#  (1, 1.51911),
#  (1, 1.51735),
#  (1, 1.5175),
#  (1, 1.51966),
#  (1, 1.51736),
#  (1, 1.51751),
#  (1, 1.5172),
#  (1, 1.51764),
#  (1, 1.51793),
#  (1, 1.51721),
#  (1, 1.51768),
#  (1, 1.51784),
#  (1, 1.51768),
#  (1, 1.51747),
#  (1, 1.51775),
#  (1, 1.51753),
#  (1, 1.51783),
#  (1, 1.51567),
#  (1, 1.51909),
#  (1, 1.51797),
#  (1, 1.52213),
#  (1, 1.52213),
#  (1, 1.51793),
#  (1, 1.51755),
#  (1, 1.51779),
#  (1, 1.5221),
#  (1, 1.51786),
#  (1, 1.519),
#  (1, 1.51869),
#  (1, 1.52667),
#  (1, 1.52223),
#  (1, 1.51898),
#  (1, 1.5232),
#  (1, 1.51926),
#  (1, 1.51808),
#  (1, 1.51837),
#  (1, 1.51778),
#  (1, 1.51769),
#  (1, 1.51215),
#  (1, 1.51824),
#  (1, 1.51754),
#  (1, 1.51754),
#  (1, 1.51905),
#  (1, 1.51977),
# ...

# %%
cursor.execute("SELECT col, count(col), col11 FROM lec1_db.glass_table GROUP BY col")

# %%
cursor.fetchall()
# Out:
# [(6, 2, 1),
#  (2, 1, 1),
#  (3, 1, 1),
#  (7, 1, 1),
#  (8, 1, 1),
#  (9, 1, 1),
#  (10, 1, 1),
#  (11, 1, 1),
#  (12, 1, 1),
#  (13, 1, 1),
#  (14, 1, 1),
#  (15, 1, 1),
#  (16, 1, 1),
#  (17, 1, 1),
#  (18, 1, 1),
#  (19, 1, 1),
#  (20, 1, 1),
#  (21, 1, 1),
#  (22, 1, 1),
#  (23, 1, 1),
#  (24, 1, 1),
#  (25, 1, 1),
#  (26, 1, 1),
#  (27, 1, 1),
#  (28, 1, 1),
#  (29, 1, 1),
#  (30, 1, 1),
#  (31, 1, 1),
#  (32, 1, 1),
#  (33, 1, 1),
#  (34, 1, 1),
#  (35, 1, 1),
#  (36, 1, 1),
#  (37, 1, 1),
#  (38, 1, 1),
#  (39, 1, 1),
#  (40, 1, 1),
#  (41, 1, 1),
#  (42, 1, 1),
#  (43, 1, 1),
#  (44, 1, 1),
#  (45, 1, 1),
#  (46, 1, 1),
#  (47, 1, 1),
#  (48, 1, 1),
#  (49, 1, 1),
#  (50, 1, 1),
#  (51, 1, 1),
#  (52, 1, 1),
#  (53, 1, 1),
#  (54, 1, 1),
#  (55, 1, 1),
#  (56, 1, 1),
#  (57, 1, 1),
#  (58, 1, 1),
#  (59, 1, 1),
#  (60, 1, 1),
#  (61, 1, 1),
#  (62, 1, 1),
#  (63, 1, 1),
#  (64, 1, 1),
#  (65, 1, 1),
#  (66, 1, 1),
#  (67, 1, 1),
#  (68, 1, 1),
#  (69, 1, 1),
#  (70, 1, 1),
# ...

# %%
cursor.execute("SELECT * FROM lec1_db.table1")

# %%
cursor.fetchall()
# Out:
# [(5001, 'student1', 105001, 'class11'),
#  (5002, 'student2', 105002, 'FSDS'),
#  (5003, 'student3', 105003, 'FSDS'),
#  (5004, 'student4', 105004, 'FSDS')]

# %%
cursor.execute("INSERT INTO LEC1_DB.TABLE1 VALUES(5004, 'student5', 105002, 'FSDS-5')")
cursor.execute("INSERT INTO LEC1_DB.TABLE1 VALUES(5002, 'student6', 105003, 'FSDS-4')")
cursor.execute("INSERT INTO LEC1_DB.TABLE1 VALUES(5004, 'student7', 105004, 'FSDS-2')")
dbConn.commit()

# %%
cursor.execute("SELECT * FROM lec1_db.table1")
cursor.fetchall()
# Out:
# [(5001, 'student1', 105001, 'class11'),
#  (5002, 'student2', 105002, 'FSDS'),
#  (5003, 'student3', 105003, 'FSDS'),
#  (5004, 'student4', 105004, 'FSDS'),
#  (5004, 'student5', 105002, 'FSDS-5'),
#  (5002, 'student6', 105003, 'FSDS-4'),
#  (5004, 'student7', 105004, 'FSDS-2')]

# %%
cursor.execute("SELECT col, count(*), col11 FROM lec1_db.glass_table GROUP BY col ORDER BY col")

# %%
cursor.fetchall()
# Out:
# [(2, 1, 1),
#  (3, 1, 1),
#  (6, 2, 1),
#  (7, 1, 1),
#  (8, 1, 1),
#  (9, 1, 1),
#  (10, 1, 1),
#  (11, 1, 1),
#  (12, 1, 1),
#  (13, 1, 1),
#  (14, 1, 1),
#  (15, 1, 1),
#  (16, 1, 1),
#  (17, 1, 1),
#  (18, 1, 1),
#  (19, 1, 1),
#  (20, 1, 1),
#  (21, 1, 1),
#  (22, 1, 1),
#  (23, 1, 1),
#  (24, 1, 1),
#  (25, 1, 1),
#  (26, 1, 1),
#  (27, 1, 1),
#  (28, 1, 1),
#  (29, 1, 1),
#  (30, 1, 1),
#  (31, 1, 1),
#  (32, 1, 1),
#  (33, 1, 1),
#  (34, 1, 1),
#  (35, 1, 1),
#  (36, 1, 1),
#  (37, 1, 1),
#  (38, 1, 1),
#  (39, 1, 1),
#  (40, 1, 1),
#  (41, 1, 1),
#  (42, 1, 1),
#  (43, 1, 1),
#  (44, 1, 1),
#  (45, 1, 1),
#  (46, 1, 1),
#  (47, 1, 1),
#  (48, 1, 1),
#  (49, 1, 1),
#  (50, 1, 1),
#  (51, 1, 1),
#  (52, 1, 1),
#  (53, 1, 1),
#  (54, 1, 1),
#  (55, 1, 1),
#  (56, 1, 1),
#  (57, 1, 1),
#  (58, 1, 1),
#  (59, 1, 1),
#  (60, 1, 1),
#  (61, 1, 1),
#  (62, 1, 1),
#  (63, 1, 1),
#  (64, 1, 1),
#  (65, 1, 1),
#  (66, 1, 1),
#  (67, 1, 1),
#  (68, 1, 1),
#  (69, 1, 1),
#  (70, 1, 1),
# ...

# %%
cursor.execute("SELECT * FROM lec1_db.table1")
cursor.fetchall()
# Out:
# [(5001, 'student1', 105001, 'class11'),
#  (5002, 'student2', 105002, 'FSDS'),
#  (5003, 'student3', 105003, 'FSDS'),
#  (5004, 'student4', 105004, 'FSDS'),
#  (5004, 'student5', 105002, 'FSDS-5'),
#  (5002, 'student6', 105003, 'FSDS-4'),
#  (5004, 'student7', 105004, 'FSDS-2')]

# %%
cursor.execute("SELECT studentid, name, class FROM lec1_db.table1 GROUP BY class")

# %%
cursor.fetchall()
# Out:
# [(5001, 'student1', 'class11'),
#  (5002, 'student2', 'FSDS'),
#  (5004, 'student5', 'FSDS-5'),
#  (5002, 'student6', 'FSDS-4'),
#  (5004, 'student7', 'FSDS-2')]

# %%
query = 'SELECT count(*) FROM lec1_db.table1 WHERE class = "FSDS"'
cursor.execute(query)
cursor.fetchall()
# Out:
# [(3,)]

# %%
cursor.execute("select count(studentid), name, class FROM lec1_db.table1 GROUP BY studentid")

# %%
cursor.fetchall()
# Out:
# [(1, 'student1', 'class11'),
#  (2, 'student2', 'FSDS'),
#  (1, 'student3', 'FSDS'),
#  (3, 'student4', 'FSDS')]

# %%
cursor.execute("select count(studentid), name, class FROM lec1_db.table1 GROUP BY class")

# %%
cursor.fetchall()
# Out:
# [(1, 'student1', 'class11'),
#  (3, 'student2', 'FSDS'),
#  (1, 'student5', 'FSDS-5'),
#  (1, 'student6', 'FSDS-4'),
#  (1, 'student7', 'FSDS-2')]

# %%
cursor.execute("select count(*), class FROM lec1_db.table1 GROUP BY class")

# %%
cursor.fetchall()
# Out:
# [(1, 'class11'), (3, 'FSDS'), (1, 'FSDS-5'), (1, 'FSDS-4'), (1, 'FSDS-2')]

# %%
cursor.execute("select count(*), studentid FROM lec1_db.table1 GROUP BY studentid")
cursor.fetchall()
# Out:
# [(1, 5001), (2, 5002), (1, 5003), (3, 5004)]

# %%
cursor.execute("DROP TABLE lec1_db.table1")
dbConn.commit()

# %%
cursor.execute("USE lec1_db")

# %%
cursor.execute("SHOW TABLES")
cursor.fetchall()
# Out:
# [('glass_table',), ('glass_table2',)]

# %%
cursor.execute("SELECT * FROM lec1_db.glass_table")
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("SELECT * FROM lec1_db.glass_table WHERE col = 11 OR col11 = 3")
cursor.fetchall()
# Out:
# [(11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (147, 1.51769, 13.65, 3.66, 1.11, 72.77, 0.11, 8.6, 0.0, 0.0, 3),
#  (148, 1.5161, 13.33, 3.53, 1.34, 72.67, 0.56, 8.33, 0.0, 0.0, 3),
#  (149, 1.5167, 13.24, 3.57, 1.38, 72.7, 0.56, 8.44, 0.0, 0.1, 3),
#  (150, 1.51643, 12.16, 3.52, 1.35, 72.89, 0.57, 8.53, 0.0, 0.0, 3),
#  (151, 1.51665, 13.14, 3.45, 1.76, 72.48, 0.6, 8.38, 0.0, 0.17, 3),
#  (152, 1.52127, 14.32, 3.9, 0.83, 71.5, 0.0, 9.49, 0.0, 0.0, 3),
#  (153, 1.51779, 13.64, 3.65, 0.65, 73.0, 0.06, 8.93, 0.0, 0.0, 3),
#  (154, 1.5161, 13.42, 3.4, 1.22, 72.69, 0.59, 8.32, 0.0, 0.0, 3),
#  (155, 1.51694, 12.86, 3.58, 1.31, 72.61, 0.61, 8.79, 0.0, 0.0, 3),
#  (156, 1.51646, 13.04, 3.4, 1.26, 73.01, 0.52, 8.58, 0.0, 0.0, 3),
#  (157, 1.51655, 13.41, 3.39, 1.28, 72.64, 0.52, 8.65, 0.0, 0.0, 3),
#  (158, 1.52121, 14.03, 3.76, 0.58, 71.79, 0.11, 9.65, 0.0, 0.0, 3),
#  (159, 1.51776, 13.53, 3.41, 1.52, 72.04, 0.58, 8.79, 0.0, 0.0, 3),
# ...

# %%
cursor.execute("SELECT * FROM lec1_db.glass_table WHERE col = 11 AND col11 = 3")
cursor.fetchall()
# Out:
# []

# %%
# Pattern
cursor.execute('SELECT * FROM lec1_db.glass_table WHERE col2 LIKE "1.515%" ')
cursor.fetchall()
# Out:
# [(6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (36, 1.51567, 13.29, 3.45, 1.21, 72.74, 0.56, 8.57, 0.0, 0.0, 1),
#  (71, 1.51574, 14.86, 3.67, 1.74, 71.87, 0.16, 7.36, 0.0, 0.12, 2),
#  (73, 1.51593, 13.09, 3.59, 1.52, 73.1, 0.67, 7.83, 0.0, 0.0, 2),
#  (75, 1.51596, 13.02, 3.56, 1.54, 73.11, 0.72, 7.9, 0.0, 0.0, 2),
#  (76, 1.5159, 13.02, 3.58, 1.51, 73.12, 0.69, 7.96, 0.0, 0.0, 2),
#  (80, 1.5159, 12.82, 3.52, 1.9, 72.86, 0.69, 7.97, 0.0, 0.0, 2),
#  (81, 1.51592, 12.86, 3.52, 2.12, 72.66, 0.69, 7.97, 0.0, 0.0, 2),
#  (82, 1.51593, 13.25, 3.45, 1.43, 73.17, 0.61, 7.86, 0.0, 0.0, 2),
#  (84, 1.51594, 13.09, 3.52, 1.55, 72.87, 0.68, 8.05, 0.0, 0.09, 2),
#  (87, 1.51569, 13.24, 3.49, 1.47, 73.25, 0.38, 8.03, 0.0, 0.0, 2),
#  (93, 1.51588, 13.12, 3.41, 1.58, 73.26, 0.07, 8.39, 0.0, 0.19, 2),
# ...

# %%
cursor.execute('SELECT * FROM lec1_db.glass_table ORDER BY col2')
cursor.fetchall()
# Out:
# [(185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (57, 1.51215, 12.99, 3.47, 1.12, 72.98, 0.62, 8.35, 0.0, 0.31, 1),
#  (181, 1.51299, 14.4, 1.74, 1.54, 74.55, 0.0, 7.59, 0.0, 0.0, 6),
#  (172, 1.51316, 13.02, 0.0, 3.04, 70.48, 6.21, 6.96, 0.0, 0.0, 5),
#  (173, 1.51321, 13.0, 0.0, 3.02, 70.7, 6.21, 6.93, 0.0, 0.0, 5),
#  (85, 1.51409, 14.25, 3.09, 2.08, 72.28, 1.1, 7.08, 0.0, 0.0, 2),
#  (201, 1.51508, 15.15, 0.0, 2.25, 73.5, 0.0, 8.34, 0.63, 0.0, 7),
#  (164, 1.51514, 14.01, 2.68, 3.5, 69.89, 1.68, 5.87, 2.2, 0.0, 5),
#  (203, 1.51514, 14.85, 0.0, 2.42, 73.72, 0.0, 8.39, 0.56, 0.0, 7),
#  (199, 1.51531, 14.38, 0.0, 2.66, 73.1, 0.04, 9.08, 0.64, 0.0, 7),
#  (196, 1.51545, 14.14, 0.0, 2.68, 73.39, 0.08, 9.07, 0.61, 0.05, 7),
#  (197, 1.51556, 13.87, 0.0, 2.54, 73.23, 0.14, 9.41, 0.81, 0.01, 7),
#  (36, 1.51567, 13.29, 3.45, 1.21, 72.74, 0.56, 8.57, 0.0, 0.0, 1),
# ...

# %%
cursor.execute('SELECT * FROM lec1_db.glass_table ORDER BY col2 DESC')
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2),
#  (107, 1.53125, 10.73, 0.0, 2.1, 69.81, 0.58, 13.3, 3.15, 0.28, 2),
#  (113, 1.52777, 12.64, 0.0, 0.67, 72.02, 0.06, 14.4, 0.0, 0.0, 2),
#  (112, 1.52739, 11.02, 0.0, 0.75, 73.08, 0.0, 14.96, 0.0, 0.0, 2),
#  (104, 1.52725, 13.8, 3.15, 0.66, 70.57, 0.08, 11.64, 0.0, 0.0, 2),
#  (48, 1.52667, 13.99, 3.7, 0.71, 71.57, 0.02, 9.82, 0.0, 0.1, 1),
#  (111, 1.52664, 11.23, 0.0, 0.77, 73.21, 0.0, 14.68, 0.0, 0.0, 2),
#  (132, 1.52614, 13.7, 0.0, 1.36, 71.24, 0.19, 13.44, 0.0, 0.1, 2),
#  (106, 1.52475, 11.45, 0.0, 1.88, 72.19, 0.81, 13.24, 0.0, 0.34, 2),
#  (105, 1.5241, 13.83, 2.9, 1.17, 71.15, 0.08, 10.79, 0.0, 0.0, 2),
#  (171, 1.52369, 13.44, 0.0, 1.58, 72.22, 0.32, 12.24, 0.0, 0.0, 5),
#  (190, 1.52365, 15.79, 1.83, 1.31, 70.43, 0.31, 8.61, 1.68, 0.0, 7),
#  (51, 1.5232, 13.72, 3.72, 0.51, 71.75, 0.09, 10.06, 0.0, 0.16, 1),
# ...

# %% [markdown]
# ### Nested Query

# %%
query = "SELECT * FROM (SELECT * FROM lec1_db.glass_table WHERE col > 112) AS gt WHERE col11 = 2"
cursor.execute(query)
cursor.fetchall()
# Out:
# [(113, 1.52777, 12.64, 0.0, 0.67, 72.02, 0.06, 14.4, 0.0, 0.0, 2),
#  (114, 1.51892, 13.46, 3.83, 1.26, 72.55, 0.57, 8.21, 0.0, 0.14, 2),
#  (115, 1.51847, 13.1, 3.97, 1.19, 72.44, 0.6, 8.43, 0.0, 0.0, 2),
#  (116, 1.51846, 13.41, 3.89, 1.33, 72.38, 0.51, 8.28, 0.0, 0.0, 2),
#  (117, 1.51829, 13.24, 3.9, 1.41, 72.33, 0.55, 8.31, 0.0, 0.1, 2),
#  (118, 1.51708, 13.72, 3.68, 1.81, 72.06, 0.64, 7.88, 0.0, 0.0, 2),
#  (119, 1.51673, 13.3, 3.64, 1.53, 72.53, 0.65, 8.03, 0.0, 0.29, 2),
#  (120, 1.51652, 13.56, 3.57, 1.47, 72.45, 0.64, 7.96, 0.0, 0.0, 2),
#  (121, 1.51844, 13.25, 3.76, 1.32, 72.4, 0.58, 8.42, 0.0, 0.0, 2),
#  (122, 1.51663, 12.93, 3.54, 1.62, 72.96, 0.64, 8.03, 0.0, 0.21, 2),
#  (123, 1.51687, 13.23, 3.54, 1.48, 72.84, 0.56, 8.1, 0.0, 0.0, 2),
#  (124, 1.51707, 13.48, 3.48, 1.71, 72.52, 0.62, 7.99, 0.0, 0.0, 2),
#  (125, 1.52177, 13.2, 3.68, 1.15, 72.75, 0.54, 8.52, 0.0, 0.0, 2),
#  (126, 1.51872, 12.93, 3.66, 1.56, 72.51, 0.58, 8.55, 0.0, 0.12, 2),
# ...

# %%
query = "SELECT * FROM lec1_db.glass_table GROUP BY col HAVING count(col) >= 2"
cursor.execute(query)
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1)]

# %% [markdown]
# ## SQL Assignment

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
1 . take a data set from attached URL https://archive.ics.uci.edu/ml/datasets/Car+Evaluation
2 . create a database called as cardataset
3 . create a table called as car with a column name given in dataset description
4 . Dump all the data into car table 
5 . try to check weather all the data is aviable inside your table or not 
6 . try to group all the data with COL1 AND count occurences of each and every record based on col1 value 
7 . Try to filter a record where col 3 value will be 4 .
8.  Try to update a col 3 value with 8 whereever you have value equal to 2 
9 . try to delete table 
10 .   Try to delete database
